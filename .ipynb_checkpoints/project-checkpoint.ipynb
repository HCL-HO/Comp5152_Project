# %%
import pandas as pd
import csv
from collections import Counter

# %%
amazon_sale = pd.read_csv('data/Amazon Sale Report.csv', sep=',')
# Out:
# /var/folders/pt/wl3z1yr91qbfxjcs0bnz5c0r0000gn/T/ipykernel_87031/2294166161.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   amazon_sale = pd.read_csv('data/Amazon Sale Report.csv', sep=',')

# %%
print(amazon_sale.columns)
print(amazon_sale.shape)
# Out:
# Index(['index', 'Order ID', 'Date', 'Status', 'Fulfilment', 'Sales Channel ',
#        'ship-service-level', 'Style', 'SKU', 'Category', 'Size', 'ASIN',
#        'Courier Status', 'Qty', 'currency', 'Amount', 'ship-city',
#        'ship-state', 'ship-postal-code', 'ship-country', 'promotion-ids',
#        'B2B', 'fulfilled-by', 'Unnamed: 22'],
#       dtype='object')
# (128975, 24)

# %%
# Counter(amazon_sale['ASIN'].tolist())

# %%
#total number of items
print(amazon_sale['ASIN'].nunique())
print(amazon_sale['Order ID'].nunique())
#buy more than one item in a transaction
duplicate_orders = amazon_sale[amazon_sale.duplicated(subset ='Order ID')]

#items that have enough appearance in the item sets
frequent_items_ids = duplicate_orders[duplicate_orders['ASIN'].map(duplicate_orders['ASIN'].value_counts()) > 20]['Order ID']
interested_sales = amazon_sale[amazon_sale['Order ID'].isin(frequent_items_ids)][['Order ID', 'ASIN']]
print(interested_sales['ASIN'].unique().size)
# Out:
# 7190
# 120378
# 88

# %%
basket = interested_sales.groupby(['Order ID', 'ASIN']).size().reset_index(name = 'Count')
print(basket)
# Out:
#                 Order ID        ASIN  Count
# 0    171-1597237-7059516  B09SDX13G7      1
# 1    171-1597237-7059516  B09SDXRYBG      1
# 2    171-1614212-0216336  B09SDXRYBG      1
# 3    171-1614212-0216336  B09SDY9SQ6      1
# 4    171-1687588-5890754  B09SDXFFQ1      1
# ..                   ...         ...    ...
# 223  408-5454943-9201928  B09SDXRYBG      1
# 224  408-7304435-2235565  B08RP3LHNB      1
# 225  408-7304435-2235565  B09SDY8DCT      1
# 226  408-7522491-5998736  B09SDXFFQ1      1
# 227  408-7522491-5998736  B09SDYL6L1      1
#
# [228 rows x 3 columns]

# %%
# basket = amazon_sale.groupby(['Order ID', 'ASIN']).size().reset_index(name = 'Count')

# %%
my_basket = (basket.groupby(['Order ID', 'ASIN'])['Count'].sum().unstack().reset_index().fillna(0).set_index('Order ID'))

# %%
print(my_basket)
# Out:
# ASIN                 B06Y5CFQSQ  B077M6KWYJ  B0783Q5HMF  B07GRVC75J  \
# Order ID
# 171-1597237-7059516         0.0         0.0         0.0         0.0
# 171-1614212-0216336         0.0         0.0         0.0         0.0
# 171-1687588-5890754         0.0         0.0         0.0         0.0
# 171-3283789-8893159         0.0         0.0         0.0         0.0
# 171-3494553-7071538         0.0         0.0         0.0         0.0
# ...                         ...         ...         ...         ...
# 408-4128435-6095562         0.0         0.0         0.0         0.0
# 408-4521661-0278767         0.0         0.0         0.0         0.0
# 408-5454943-9201928         0.0         0.0         0.0         0.0
# 408-7304435-2235565         0.0         0.0         0.0         0.0
# 408-7522491-5998736         0.0         0.0         0.0         0.0
#
# ASIN                 B07HWMZ61T  B07R51FQDF  B07ZYQQZ28  B081X4S825  \
# Order ID
# 171-1597237-7059516         0.0         0.0         0.0         0.0
# 171-1614212-0216336         0.0         0.0         0.0         0.0
# 171-1687588-5890754         0.0         0.0         0.0         0.0
# 171-3283789-8893159         0.0         0.0         0.0         0.0
# 171-3494553-7071538         0.0         0.0         0.0         0.0
# ...                         ...         ...         ...         ...
# 408-4128435-6095562         0.0         0.0         0.0         0.0
# 408-4521661-0278767         0.0         0.0         0.0         0.0
# 408-5454943-9201928         0.0         0.0         0.0         0.0
# 408-7304435-2235565         0.0         0.0         0.0         0.0
# 408-7522491-5998736         0.0         0.0         0.0         0.0
#
# ASIN                 B082W7GVH7  B082W8B28G  ...  B09SDZ64HF  B09TH33GBM  \
# Order ID                                     ...
# 171-1597237-7059516         0.0         0.0  ...         0.0         0.0
# 171-1614212-0216336         0.0         0.0  ...         0.0         0.0
# 171-1687588-5890754         0.0         0.0  ...         0.0         0.0
# 171-3283789-8893159         0.0         0.0  ...         0.0         0.0
# 171-3494553-7071538         0.0         0.0  ...         0.0         0.0
# ...                         ...         ...  ...         ...         ...
# 408-4128435-6095562         0.0         0.0  ...         0.0         0.0
# 408-4521661-0278767         0.0         0.0  ...         0.0         0.0
# 408-5454943-9201928         0.0         1.0  ...         0.0         0.0
# 408-7304435-2235565         0.0         0.0  ...         0.0         0.0
# 408-7522491-5998736         0.0         0.0  ...         0.0         0.0
#
# ASIN                 B09TH43NW5  B09TH59KYD  B09TH7GXJW  B09VZ6HK5S  \
# Order ID
# 171-1597237-7059516         0.0         0.0         0.0         0.0
# 171-1614212-0216336         0.0         0.0         0.0         0.0
# 171-1687588-5890754         0.0         0.0         0.0         0.0
# 171-3283789-8893159         0.0         0.0         0.0         0.0
# 171-3494553-7071538         0.0         0.0         0.0         0.0
# ...                         ...         ...         ...         ...
# 408-4128435-6095562         0.0         0.0         0.0         0.0
# 408-4521661-0278767         0.0         0.0         0.0         0.0
# 408-5454943-9201928         0.0         0.0         0.0         0.0
# 408-7304435-2235565         0.0         0.0         0.0         0.0
# 408-7522491-5998736         0.0         0.0         0.0         0.0
#
# ASIN                 B09Y3DC7D9  B09YYPWNT8  B0B3MQHKT1  B0B3NBYD9W
# Order ID
# 171-1597237-7059516         0.0         0.0         0.0         0.0
# 171-1614212-0216336         0.0         0.0         0.0         0.0
# 171-1687588-5890754         0.0         0.0         0.0         0.0
# 171-3283789-8893159         0.0         0.0         0.0         0.0
# 171-3494553-7071538         0.0         0.0         0.0         0.0
# ...                         ...         ...         ...         ...
# 408-4128435-6095562         0.0         0.0         0.0         0.0
# 408-4521661-0278767         0.0         0.0         0.0         0.0
# 408-5454943-9201928         0.0         0.0         0.0         0.0
# 408-7304435-2235565         0.0         0.0         0.0         0.0
# 408-7522491-5998736         0.0         0.0         0.0         0.0
#
# [98 rows x 88 columns]

# %%
def encode_data(datapoint):
 if datapoint <= 0:
     return 0
 else:
     return 1

# %%
my_basket = my_basket.applymap(encode_data)
print(my_basket.head())
print(my_basket.isna().sum())
# Out:
# ASIN                 B06Y5CFQSQ  B077M6KWYJ  B0783Q5HMF  B07GRVC75J  \
# Order ID
# 171-1597237-7059516           0           0           0           0
# 171-1614212-0216336           0           0           0           0
# 171-1687588-5890754           0           0           0           0
# 171-3283789-8893159           0           0           0           0
# 171-3494553-7071538           0           0           0           0
#
# ASIN                 B07HWMZ61T  B07R51FQDF  B07ZYQQZ28  B081X4S825  \
# Order ID
# 171-1597237-7059516           0           0           0           0
# 171-1614212-0216336           0           0           0           0
# 171-1687588-5890754           0           0           0           0
# 171-3283789-8893159           0           0           0           0
# 171-3494553-7071538           0           0           0           0
#
# ASIN                 B082W7GVH7  B082W8B28G  ...  B09SDZ64HF  B09TH33GBM  \
# Order ID                                     ...
# 171-1597237-7059516           0           0  ...           0           0
# 171-1614212-0216336           0           0  ...           0           0
# 171-1687588-5890754           0           0  ...           0           0
# 171-3283789-8893159           0           0  ...           0           0
# 171-3494553-7071538           0           0  ...           0           0
#
# ASIN                 B09TH43NW5  B09TH59KYD  B09TH7GXJW  B09VZ6HK5S  \
# Order ID
# 171-1597237-7059516           0           0           0           0
# 171-1614212-0216336           0           0           0           0
# 171-1687588-5890754           0           0           0           0
# 171-3283789-8893159           0           0           0           0
# 171-3494553-7071538           0           0           0           0
#
# ASIN                 B09Y3DC7D9  B09YYPWNT8  B0B3MQHKT1  B0B3NBYD9W
# Order ID
# 171-1597237-7059516           0           0           0           0
# 171-1614212-0216336           0           0           0           0
# 171-1687588-5890754           0           0           0           0
# 171-3283789-8893159           0           0           0           0
# 171-3494553-7071538           0           0           0           0
#
# [5 rows x 88 columns]
# ASIN
# B06Y5CFQSQ    0
# B077M6KWYJ    0
# B0783Q5HMF    0
# B07GRVC75J    0
# B07HWMZ61T    0
#              ..
# B09VZ6HK5S    0
# B09Y3DC7D9    0
# B09YYPWNT8    0
# B0B3MQHKT1    0
# B0B3NBYD9W    0
# Length: 88, dtype: int64

# %%
import mlxtend as ml
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
new_items = apriori(my_basket, min_support=0.01, use_colnames=True)
# Out:
# /Users/eho/anaconda3/lib/python3.11/site-packages/mlxtend/frequent_patterns/fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
print(new_items)
# Out:
#       support                                           itemsets
# 0    0.010204                                       (B06Y5CFQSQ)
# 1    0.010204                                       (B077M6KWYJ)
# 2    0.010204                                       (B0783Q5HMF)
# 3    0.010204                                       (B07GRVC75J)
# 4    0.010204                                       (B07HWMZ61T)
# ..        ...                                                ...
# 435  0.010204  (B09SDY7MHD, B09SDXSQ33, B09SDXFFQ1, B09SDZ64H...
# 436  0.010204  (B09SDY8DCT, B09SDXSQ33, B09SDXFFQ1, B09SDZ64H...
# 437  0.010204  (B09SDY7MHD, B09SDY8DCT, B09SDXFFQ1, B09SDZ64H...
# 438  0.010204  (B09SDY7MHD, B09SDY8DCT, B09SDXSQ33, B09SDZ64H...
# 439  0.010204  (B09SDY7MHD, B09SDY8DCT, B09SDXSQ33, B09SDXFFQ...
#
# [440 rows x 2 columns]

# %%
new_rules = association_rules(new_items, metric='lift', min_threshold=0.5)
print(new_rules.shape[0])
print(new_rules.head())
# Out:
# 3462
#     antecedents   consequents  antecedent support  consequent support  \
# 0  (B081X4S825)  (B06Y5CFQSQ)            0.020408            0.010204
# 1  (B06Y5CFQSQ)  (B081X4S825)            0.010204            0.020408
# 2  (B06Y5CFQSQ)  (B082W7GVH7)            0.010204            0.010204
# 3  (B082W7GVH7)  (B06Y5CFQSQ)            0.010204            0.010204
# 4  (B06Y5CFQSQ)  (B09KXT4VG7)            0.010204            0.020408
#
#     support  confidence  lift  leverage  conviction  zhangs_metric
# 0  0.010204         0.5  49.0  0.009996    1.979592       1.000000
# 1  0.010204         1.0  49.0  0.009996         inf       0.989691
# 2  0.010204         1.0  98.0  0.010100         inf       1.000000
# 3  0.010204         1.0  98.0  0.010100         inf       1.000000
# 4  0.010204         1.0  49.0  0.009996         inf       0.989691

# %%
interesting_rules = new_rules[(new_rules['lift']> 1) & (new_rules['confidence'] >= 0.5)]
print(interesting_rules.shape[0])
print(interesting_rules.head())
# Out:
# 2947
#     antecedents   consequents  antecedent support  consequent support  \
# 0  (B081X4S825)  (B06Y5CFQSQ)            0.020408            0.010204
# 1  (B06Y5CFQSQ)  (B081X4S825)            0.010204            0.020408
# 2  (B06Y5CFQSQ)  (B082W7GVH7)            0.010204            0.010204
# 3  (B082W7GVH7)  (B06Y5CFQSQ)            0.010204            0.010204
# 4  (B06Y5CFQSQ)  (B09KXT4VG7)            0.010204            0.020408
#
#     support  confidence  lift  leverage  conviction  zhangs_metric
# 0  0.010204         0.5  49.0  0.009996    1.979592       1.000000
# 1  0.010204         1.0  49.0  0.009996         inf       0.989691
# 2  0.010204         1.0  98.0  0.010100         inf       1.000000
# 3  0.010204         1.0  98.0  0.010100         inf       1.000000
# 4  0.010204         1.0  49.0  0.009996         inf       0.989691

# %%
interesting_rules.drop(columns = ['antecedent support', 'consequent support', 'conviction', 'leverage'])
# Out:
#                    antecedents  \
# 0                 (B081X4S825)
# 1                 (B06Y5CFQSQ)
# 2                 (B06Y5CFQSQ)
# 3                 (B082W7GVH7)
# 4                 (B06Y5CFQSQ)
# ...                        ...
# 3453  (B09SDY9SQ6, B09SDZ64HF)
# 3454  (B09SDYQ3WG, B09SDY9SQ6)
# 3455              (B09SDY7MHD)
# 3457              (B09SDXSQ33)
# 3459              (B09SDZ64HF)
#
#                                             consequents   support  confidence  \
# 0                                          (B06Y5CFQSQ)  0.010204         0.5
# 1                                          (B081X4S825)  0.010204         1.0
# 2                                          (B082W7GVH7)  0.010204         1.0
# 3                                          (B06Y5CFQSQ)  0.010204         1.0
# 4                                          (B09KXT4VG7)  0.010204         1.0
# ...                                                 ...       ...         ...
# 3453  (B09SDY7MHD, B09SDY8DCT, B09SDXSQ33, B09SDXFFQ...  0.010204         1.0
# 3454  (B09SDY7MHD, B09SDY8DCT, B09SDXSQ33, B09SDXFFQ...  0.010204         1.0
# 3455  (B09SDY8DCT, B09SDXSQ33, B09SDXFFQ1, B09SDZ64H...  0.010204         1.0
# 3457  (B09SDY7MHD, B09SDY8DCT, B09SDXFFQ1, B09SDZ64H...  0.010204         0.5
# 3459  (B09SDY7MHD, B09SDY8DCT, B09SDXSQ33, B09SDXFFQ...  0.010204         1.0
#
#       lift  zhangs_metric
# 0     49.0       1.000000
# 1     49.0       0.989691
# 2     98.0       1.000000
# 3     98.0       1.000000
# 4     49.0       0.989691
# ...    ...            ...
# 3453  98.0       1.000000
# 3454  98.0       1.000000
# 3455  98.0       1.000000
# 3457  49.0       1.000000
# 3459  98.0       1.000000
#
# [2947 rows x 6 columns]

# %%
# order_ids = amazon_sale[amazon_sale['ASIN'] == 'B06Y5CFQSQ']['Order ID']
# amazon_sale[amazon_sale['Order ID'].isin(order_ids)][['Order ID', 'ASIN']]
# Out:
#                    Order ID        ASIN
# 6000    171-4470641-5630702  B06Y5CFQSQ
# 13392   408-3484119-6656309  B06Y5CFQSQ
# 13393   408-3484119-6656309  B01M1L6330
# 22781   407-1789478-3730701  B06Y5CFQSQ
# 25995   408-5378850-5661927  B06Y5CFQSQ
# 26388   407-3551872-3155556  B06Y5CFQSQ
# 28250   404-3575316-7622707  B06Y5CFQSQ
# 28762   406-9667043-0009942  B06Y5CFQSQ
# 43897   171-7753030-0719569  B06Y5CFQSQ
# 69119   403-7559804-3970726  B081X4S825
# 69120   403-7559804-3970726  B082W7GVH7
# 69121   403-7559804-3970726  B06Y5CFQSQ
# 69122   403-7559804-3970726  B09NQ44RNV
# 69123   403-7559804-3970726  B09NQ4XYV9
# 69124   403-7559804-3970726  B09KXT4VG7
# 81545   402-5768714-8116318  B06Y5CFQSQ
# 88439   171-1076787-3867523  B06Y5CFQSQ
# 88704   406-4055059-4868340  B06Y5CFQSQ
# 88705   406-4055059-4868340  B01M1L6330
# 116884  402-0081130-6968376  B06Y5CFQSQ
# 117477  406-9905642-7091545  B06Y5CFQSQ
# 118987  403-3645145-4748355  B07ZYSFZ4M
# 118988  403-3645145-4748355  B099FD9VJ9
# 118989  403-3645145-4748355  B06Y5CFQSQ
# 118990  403-3645145-4748355  B08BFLKNGJ
# 118991  403-3645145-4748355  B083SMN2D7
# 122829  408-1000588-0955527  B06Y5CFQSQ
